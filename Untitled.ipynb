# %% [markdown]
# # 问题分析

# %% [markdown]
# - 目标：利用个人基本信息和通话特诊，预测用户是否为电信欺诈用户

# %% [markdown]
# - 直觉判断：
# 1. 欺诈用户的年龄不能太大也不能太小；
# 2. 欺诈用户不太可能是校园用户；
# 3. 欺诈行为的发生不太可能在夜间；
# 4. 欺诈用户的被叫次数应该较少，呼出次数较多；
# 5. 欺诈用户工作日与节假日的交往圈重合度应该较高；
# 6. 欺诈用户仅拨打一次的电话号码的数量较多，占比较高；
# 7. 欺诈用户的联系人top5/top10通话时长占比较少、次数占比较少、归属地数量较多；

# %% [markdown]
# - 任务类型：有监督的二分类任务
#
# - 评估指标：
# 1. Precision；（不好）
# 2. Recall；（不好）
# 3. F-beta-score（可设置beta>1使得查全率影响高，因为我们需要低精确度、高查全率）；
# 4. P-R曲线
# 4. ROC曲线/AUC（排序的质量）（不好）；
# 5. 代价曲线（欺诈行为发生频率低但的代价高）；

# %% [markdown]
# - 问题：样本不均衡
# 1. 验证集的划分（分层）
# 2. 评估指标的选择
# 3. 过拟合？

# %% [markdown]
# # 研究数据

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
train = pd.read_csv('./data/training.csv')

# %%
data = train.copy()

# %%
data
# Out:
#        age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0       25    2             0                1.2726               3.1250
# 1       18    2             0                8.4315               6.9767
# 2       42    1             1                5.0105               7.6923
# 3       28    2             1                1.4925               3.8462
# 4       60    1             0                0.7424               0.6472
# ...    ...  ...           ...                   ...                  ...
# 29404   22    2             0                6.3073              20.0000
# 29405    0    1             1                5.4694               6.1224
# 29406   18    1             0                4.6768               7.4074
# 29407   34    1             0                0.3208               0.7299
# 29408   44    1             0                3.2597               7.1429
#
#        called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0              87.5000              1             2            66.6667
# 1              76.7442              3             3            50.0000
# 2              49.0385              7            13            65.0000
# 3              19.2308              0            21           100.0000
# 4              37.5405             15            12            37.5000
# ...                ...            ...           ...                ...
# 29404         100.0000              0             0             0.0000
# 29405          43.8776              5             1            20.0000
# 29406          48.1481              4            13            54.1667
# 29407          27.7372              9             7            35.0000
# 29408          43.8776              8             5            27.7778
#
#        top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                  72.0020             43.7500                  3
# 1                  99.2148             88.3721                  1
# 2                  64.1474             53.8462                  2
# 3                  45.9242             19.2308                  1
# 4                  69.9878             57.2816                  3
# ...                    ...                 ...                ...
# 29404             100.0000            100.0000                  3
# 29405              99.0246             89.7959                  3
# 29406              45.3232             27.1605                  1
# 29407              82.2456             62.7737                  2
# 29408              67.6509             40.8163                  2
#
#        top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt  label
# 0                   86.5884              62.5000                   3      0
# 1                  100.0000             100.0000                   3      0
# 2                   82.2526              71.1538                   3      0
# 3                   64.0643              38.4615                   1      0
# 4                   85.1415              70.8738                   3      0
# ...                     ...                  ...                 ...    ...
# 29404              100.0000             100.0000                   3      0
# 29405               99.8302              97.9592                   3      0
# 29406               62.7430              41.9753                   1      0
# 29407               91.2374              74.4526                   2      0
# 29408               83.5715              58.1633                   3      0
#
# [29409 rows x 16 columns]

# %%
data.info()
# 注意rate特征的单位是%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29409 entries, 0 to 29408
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   29409 non-null  int64
#  1   sex                   29409 non-null  int64
#  2   is_camp_user          29409 non-null  int64
#  3   night_call_dura_rate  29409 non-null  float64
#  4   night_call_cnt_rate   29409 non-null  float64
#  5   called_cnt_rate       29409 non-null  float64
#  6   contact_ratio         29409 non-null  int64
#  7   once_numbers          29409 non-null  int64
#  8   once_numbers_rate     29409 non-null  float64
#  9   top5_call_dura_rate   29409 non-null  float64
#  10  top5_call_cnt_rate    29409 non-null  float64
#  11  top5_opp_belo_cnt     29409 non-null  int64
#  12  top10_call_dura_rate  29409 non-null  float64
#  13  top10_call_cnt_rate   29409 non-null  float64
#  14  top10_opp_belo_cnt    29409 non-null  int64
#  15  label                 29409 non-null  int64
# dtypes: float64(8), int64(8)
# memory usage: 3.6 MB

# %%
data['contact_ratio']
# 这个重合度指的应该是拨打对象相同的人数
# Out:
# 0         1
# 1         3
# 2         7
# 3         0
# 4        15
#          ..
# 29404     0
# 29405     5
# 29406     4
# 29407     9
# 29408     8
# Name: contact_ratio, Length: 29409, dtype: int64

# %% [markdown]
# 总体数据特征分布分析：
# - 样本的年龄主要分布在20-60之间，20-40间居多；
#
# - 样本的性别分布不是太均衡；
# - 样本主要为非校园用户；
# - 大部分样本的夜间通话时长/次数占比低于10%，可能说明欺诈用户的夜间通话时长/次数占比高（经验证该猜想错误）；
# - 夜间通话时长/次数占比指标分布相似（相关性较高），考虑进行特征处理；
# - 被呼叫次数占比分布近似高斯分布，处在分布两端特别是偏低的那一部分可能是欺诈用户（经过验证，偏低的那一部分是欺诈用户的可能性高，偏高那部分是欺诈用户的可能性较低）；
# - 大部分样本的工作日与节假日交往圈重合度较低，说明重合度较高的用户可能是欺诈用户（经验证该猜想错误）；
# - 大部分样本仅拨打一次的电话的数量较低（小于10次），有个别甚至超过3000次，该指标超过50则是欺诈用户的可能性大；
# - 仅拨打一次电话的数量占比分布呈现“W”形状，分布两头的部分可能是欺诈用户（已验证）；
# - 联系人top5通话时长占比分布呈递增趋势，占比较低那部分可能是欺诈用户（已验证）；
# - 联系人top5通话次数占比大部分集中在50%-90%，占比较低那部分可能是欺诈用户（已验证）；
# - 联系人top5号码归属地数量主要集中在1-3，4-5可能为欺诈用户（经验证该猜想错误）；
# - top10的通话时长占比分布和次数占比分布相似，top10的通话时长占比分布与top5相似，但次数占比分布相似与top5不相似，考虑特征处理；
# - 联系人top10号码归属地数量主要集中在5以内，尾部用户可能是欺诈用户（已验证）
# - 样本标签分布不均衡（任务性质决定），需要在划分验证集是根据标签进行分层；

# %%
data.describe()
# Out:
#                 age           sex  is_camp_user  night_call_dura_rate  \
# count  29409.000000  29409.000000  29409.000000          29409.000000
# mean      38.884117      1.437145      0.152334              6.363872
# std       14.410745      0.516132      0.359351             12.279179
# min        0.000000      1.000000      0.000000              0.000000
# 25%       28.000000      1.000000      0.000000              0.537600
# 50%       39.000000      1.000000      0.000000              1.886800
# 75%       50.000000      2.000000      0.000000              6.142100
# max      117.000000      3.000000      1.000000            100.000000
#
#        night_call_cnt_rate  called_cnt_rate  contact_ratio  once_numbers  \
# count         29409.000000     29409.000000   29409.000000  29409.000000
# mean              6.413430        54.902482       5.971097      9.149852
# std               9.553943        19.472407       6.673715     45.361686
# min               0.000000         0.000000       0.000000      0.000000
# 25%               1.492500        43.478300       2.000000      2.000000
# 50%               3.333300        54.567300       4.000000      5.000000
# 75%               7.407400        66.666700       8.000000      9.000000
# max             100.000000       100.000000     347.000000   3260.000000
#
#        once_numbers_rate  top5_call_dura_rate  top5_call_cnt_rate  \
# count       29409.000000         29409.000000        29409.000000
# mean           50.161633            78.063901           63.742208
# std            24.079010            18.532458           22.256341
# min             0.000000             0.000000            0.000000
# 25%            35.714300            67.859700           48.507500
# 50%            50.000000            81.827300           65.306100
# 75%            64.864900            92.579600           80.663000
# max           100.000000           100.000000          100.000000
#
#        top5_opp_belo_cnt  top10_call_dura_rate  top10_call_cnt_rate  \
# count       29409.000000          29409.000000         29409.000000
# mean            1.773607             89.729674            80.216229
# std             0.897999             14.951446            19.569954
# min             0.000000              0.000000             0.000000
# 25%             1.000000             85.957200            70.192300
# 50%             2.000000             94.958600            84.729100
# 75%             2.000000             99.419400            96.103900
# max             5.000000            100.000000           100.000000
#
#        top10_opp_belo_cnt         label
# count        29409.000000  29409.000000
# mean             2.415043      0.054779
# std              1.384936      0.227553
# min              0.000000      0.000000
# 25%              1.000000      0.000000
# 50%              2.000000      0.000000
# 75%              3.000000      0.000000
# max             10.000000      1.000000

# %%
data.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'is_camp_user'}>,
#         <AxesSubplot:title={'center':'night_call_dura_rate'}>],
#        [<AxesSubplot:title={'center':'night_call_cnt_rate'}>,
#         <AxesSubplot:title={'center':'called_cnt_rate'}>,
#         <AxesSubplot:title={'center':'contact_ratio'}>,
#         <AxesSubplot:title={'center':'once_numbers'}>],
#        [<AxesSubplot:title={'center':'once_numbers_rate'}>,
#         <AxesSubplot:title={'center':'top5_call_dura_rate'}>,
#         <AxesSubplot:title={'center':'top5_call_cnt_rate'}>,
#         <AxesSubplot:title={'center':'top5_opp_belo_cnt'}>],
#        [<AxesSubplot:title={'center':'top10_call_dura_rate'}>,
#         <AxesSubplot:title={'center':'top10_call_cnt_rate'}>,
#         <AxesSubplot:title={'center':'top10_opp_belo_cnt'}>,
#         <AxesSubplot:title={'center':'label'}>]], dtype=object)

# %%
normal = data[data['label']==0]
cheat = data[data['label']==1]

# %% [markdown]
# - 异常用户与正常用户分布不同的特征：
# 1. 被呼叫次数占比:：欺诈用户的被呼叫次数较少；
# 2. 一次通话数量占比：欺诈用户分布两头较中间高；
# 3. 一次通话数量：欺诈用户的一次通话数量高于100；
# 4. 联系人top5/10 通话时长占比(%)：较低那头是欺诈用户的可能性高;
# 5. 联系人top5/10 通话次数占比(%)：较低那头是欺诈用户的可能性高;
# 6. 联系人top5/10 号码归属地数量：归属地数量多的那部分是欺诈用户的可能性高;

# %%
fig = plt.figure(figsize=(20,30))
for index, columns in enumerate(data.columns):
    ax1 = fig.add_subplot(int(len(data.columns)/2),4,index*2+1)
    ax1 = normal[columns].hist()
    plt.title('normal_'+columns)
    ax2 = fig.add_subplot(int(len(data.columns)/2),4,index*2+2)
    ax2 = cheat[columns].hist(color='C1')
    plt.title('cheat_'+columns)

# %% [markdown]
# 综上所述：
# - 夜间通话时长/次数占比指标分布相似（相关性较高），考虑进行特征处理；
# - top10的通话时长占比分布和次数占比分布相似，top10的通话时长占比分布与top5相似，但次数占比分布相似与top5不相似，考虑特征处理；
# - 划分验证集时标签分层;
#
# - 被呼叫次数偏低的那一部分是欺诈用户的可能性高；
# - 仅拨打一次电话的数量比例分布呈现“W”形状，分布两头的部分可能是欺诈用户；
# - 仅拨打一次电话的数量高于100的可能是欺诈用户；
# - 联系人top5/10 通话时长占比(%)：较低那头是欺诈用户的可能性高;
# - 联系人top5/10 通话次数占比(%)：较低那头是欺诈用户的可能性高;
# - 联系人top5/10 号码归属地数量：归属地数量多的那部分是欺诈用户的可能性高;

# %% [markdown]
# 查看属性之间的相关性

# %%
corr_matrix = data.corr()

# %%
corr_matrix['label']
# 各特征与label的相关系数同样支持上述猜想
# Out:
# age                     0.032195
# sex                    -0.019179
# is_camp_user           -0.060469
# night_call_dura_rate   -0.061763
# night_call_cnt_rate    -0.090736
# called_cnt_rate        -0.209620
# contact_ratio          -0.036284
# once_numbers            0.210248
# once_numbers_rate      -0.009041
# top5_call_dura_rate    -0.280738
# top5_call_cnt_rate     -0.197689
# top5_opp_belo_cnt       0.097469
# top10_call_dura_rate   -0.389707
# top10_call_cnt_rate    -0.295857
# top10_opp_belo_cnt      0.166961
# label                   1.000000
# Name: label, dtype: float64

# %%
abs(corr_matrix['label']).sort_values(ascending=False)
# once_numbers_rate的相关系数低可能是因为处在分布两头的用户是欺诈用户的可能性高于中部，或者说该特征与label没有线性相关性
# Out:
# label                   1.000000
# top10_call_dura_rate    0.389707
# top10_call_cnt_rate     0.295857
# top5_call_dura_rate     0.280738
# once_numbers            0.210248
# called_cnt_rate         0.209620
# top5_call_cnt_rate      0.197689
# top10_opp_belo_cnt      0.166961
# top5_opp_belo_cnt       0.097469
# night_call_cnt_rate     0.090736
# night_call_dura_rate    0.061763
# is_camp_user            0.060469
# contact_ratio           0.036284
# age                     0.032195
# sex                     0.019179
# once_numbers_rate       0.009041
# Name: label, dtype: float64

# %%
corr_matrix['night_call_dura_rate'].sort_values(ascending=False)
# 夜间通话时长与夜间通话次数相关系数高达0.75
# Out:
# night_call_dura_rate    1.000000
# night_call_cnt_rate     0.750150
# top5_call_dura_rate     0.189619
# top10_opp_belo_cnt      0.148481
# top10_call_dura_rate    0.144651
# top5_opp_belo_cnt       0.142039
# top5_call_cnt_rate      0.136571
# top10_call_cnt_rate     0.130351
# once_numbers_rate       0.088693
# called_cnt_rate         0.043455
# sex                    -0.022687
# is_camp_user           -0.022839
# once_numbers           -0.036689
# label                  -0.061763
# age                    -0.163975
# contact_ratio          -0.169769
# Name: night_call_dura_rate, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ['top10_call_dura_rate', 'top10_call_cnt_rate', 'top5_call_dura_rate', 'top5_call_cnt_rate']

# %%
scatter_matrix(data[attributes], figsize=(10,10))
# top5/10的通话时长/次数呈现线性相关关系
# Out:
# array([[<AxesSubplot:xlabel='top10_call_dura_rate', ylabel='top10_call_dura_rate'>,
#         <AxesSubplot:xlabel='top10_call_cnt_rate', ylabel='top10_call_dura_rate'>,
#         <AxesSubplot:xlabel='top5_call_dura_rate', ylabel='top10_call_dura_rate'>,
#         <AxesSubplot:xlabel='top5_call_cnt_rate', ylabel='top10_call_dura_rate'>],
#        [<AxesSubplot:xlabel='top10_call_dura_rate', ylabel='top10_call_cnt_rate'>,
#         <AxesSubplot:xlabel='top10_call_cnt_rate', ylabel='top10_call_cnt_rate'>,
#         <AxesSubplot:xlabel='top5_call_dura_rate', ylabel='top10_call_cnt_rate'>,
#         <AxesSubplot:xlabel='top5_call_cnt_rate', ylabel='top10_call_cnt_rate'>],
#        [<AxesSubplot:xlabel='top10_call_dura_rate', ylabel='top5_call_dura_rate'>,
#         <AxesSubplot:xlabel='top10_call_cnt_rate', ylabel='top5_call_dura_rate'>,
#         <AxesSubplot:xlabel='top5_call_dura_rate', ylabel='top5_call_dura_rate'>,
#         <AxesSubplot:xlabel='top5_call_cnt_rate', ylabel='top5_call_dura_rate'>],
#        [<AxesSubplot:xlabel='top10_call_dura_rate', ylabel='top5_call_cnt_rate'>,
#         <AxesSubplot:xlabel='top10_call_cnt_rate', ylabel='top5_call_cnt_rate'>,
#         <AxesSubplot:xlabel='top5_call_dura_rate', ylabel='top5_call_cnt_rate'>,
#         <AxesSubplot:xlabel='top5_call_cnt_rate', ylabel='top5_call_cnt_rate'>]],
#       dtype=object)

# %% [markdown]
# 对于存在共线性的属性，采用相除的组合方式，创建新的有意义的属性；
# 但是由于这3个新属性在计算时均存在除数(night_call_cnt_rate、top5_call_cnt_rate、top10_call_cnt_rate)为0的情况，考虑将这除数为0的行去除，
# 但是又由于欺诈用户大部分的night_call_cnt_rate均为0，直接丢弃会造成本身就少的正例丢失，且丢弃行的行为本就是下下策，还会导致在测试集中分类器无法处理night_call_cnt_rate为0的数据;
# 一种方案是将0取为0.00001；
# 另一种方案是不以相除的方式处理共线性属性，选择其中与label相关性更大的那一个保留，或者根本不处理；

# %%
data['night_call_avg_dura_rate'] = data['night_call_dura_rate']/data['night_call_cnt_rate']
data['top5_call_avg_dura_rate'] = data['top5_call_dura_rate']/data['top5_call_cnt_rate']
data['top10_call_avg_dura_rate'] = data['top10_call_dura_rate']/data['top10_call_cnt_rate']

# %%
data.iloc[:, -3:].describe()
# Out:
#        night_call_avg_dura_rate  top5_call_avg_dura_rate  \
# count              2.842800e+04             29151.000000
# mean                        inf                 1.339832
# std                         NaN                 0.542278
# min                2.400024e-03                 0.515095
# 25%                2.764095e-01                 1.061518
# 50%                5.694425e-01                 1.189145
# 75%                1.101539e+00                 1.428860
# max                         inf                27.414557
#
#        top10_call_avg_dura_rate
# count              29151.000000
# mean                   1.167311
# std                    0.314712
# min                    0.670095
# 25%                    1.016656
# 50%                    1.086578
# 75%                    1.205130
# max                   22.601973

# %% [markdown]
# 对于标签不平衡的解决方法：
# - 模型层面决定选择bagging、boosting类模型
# - 数据层面的过采样、欠采样等方法暂不考虑

# %% [markdown]
# # 数据准备

# %%
data = train.copy()

# %%
data
# Out:
#        age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0       25    2             0                1.2726               3.1250
# 1       18    2             0                8.4315               6.9767
# 2       42    1             1                5.0105               7.6923
# 3       28    2             1                1.4925               3.8462
# 4       60    1             0                0.7424               0.6472
# ...    ...  ...           ...                   ...                  ...
# 29404   22    2             0                6.3073              20.0000
# 29405    0    1             1                5.4694               6.1224
# 29406   18    1             0                4.6768               7.4074
# 29407   34    1             0                0.3208               0.7299
# 29408   44    1             0                3.2597               7.1429
#
#        called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0              87.5000              1             2            66.6667
# 1              76.7442              3             3            50.0000
# 2              49.0385              7            13            65.0000
# 3              19.2308              0            21           100.0000
# 4              37.5405             15            12            37.5000
# ...                ...            ...           ...                ...
# 29404         100.0000              0             0             0.0000
# 29405          43.8776              5             1            20.0000
# 29406          48.1481              4            13            54.1667
# 29407          27.7372              9             7            35.0000
# 29408          43.8776              8             5            27.7778
#
#        top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                  72.0020             43.7500                  3
# 1                  99.2148             88.3721                  1
# 2                  64.1474             53.8462                  2
# 3                  45.9242             19.2308                  1
# 4                  69.9878             57.2816                  3
# ...                    ...                 ...                ...
# 29404             100.0000            100.0000                  3
# 29405              99.0246             89.7959                  3
# 29406              45.3232             27.1605                  1
# 29407              82.2456             62.7737                  2
# 29408              67.6509             40.8163                  2
#
#        top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt  label
# 0                   86.5884              62.5000                   3      0
# 1                  100.0000             100.0000                   3      0
# 2                   82.2526              71.1538                   3      0
# 3                   64.0643              38.4615                   1      0
# 4                   85.1415              70.8738                   3      0
# ...                     ...                  ...                 ...    ...
# 29404              100.0000             100.0000                   3      0
# 29405               99.8302              97.9592                   3      0
# 29406               62.7430              41.9753                   1      0
# 29407               91.2374              74.4526                   2      0
# 29408               83.5715              58.1633                   3      0
#
# [29409 rows x 16 columns]

# %%
class DropInvalidData(BaseEstimator, TransformerMixin):
    def __init__(self, add_night=True, add_top=True):
        self.add_night= add_night
        self.add_top = add_top
        
    def fit(self, df):
        return self
    
    def transform(self, df):
        res = df.copy()
        if self.add_night:
            res.drop(axis=0, index=res[res['night_call_cnt_rate']==0].index, inplace=True)
            return res
        
        elif self.add_top:
            res.drop(axis=0, index=res[res['top5_call_cnt_rate']==0].index, inplace=True)
            return res 
        
        return res

# %%
add_night = True
add_top = True

# %%
dropper = DropInvalidData(add_night=add_night, add_top=add_top)

# %%
data = dropper.fit_transform(data)

# %%
data.shape
# Out:
# (28426, 16)

# %%
X = data.drop(columns=['label'])
y = data['label']

# %% [markdown]
# - 对比率去除%的单位影响：除100
# - 对年龄做min-max归一化
# - 对contact_ratio做min-max归一化
# - 对归属地数量做min-max归一化
# - 对once_numbers做min-max归一化

# %%
min_max_scale_cols = ['age', 'contact_ratio', 'once_numbers', 'top5_opp_belo_cnt', 'top10_opp_belo_cnt']

# %% [markdown]
# - 添加属性组合

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_night=True, add_top=True):
        self.add_night = add_night
        self.add_top = add_top
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        res = X.copy()
        if self.add_night:
            res['night_call_avg_dura_rate'] = res['night_call_dura_rate']/res['night_call_cnt_rate']
            scaler = MinMaxScaler()
            res.loc[:, ['night_call_avg_dura_rate']] = scaler.fit_transform(res.loc[:, ['night_call_avg_dura_rate']])

        if self.add_top:
            res['top5_call_avg_dura_rate'] = res['top5_call_dura_rate']/res['top5_call_cnt_rate']
            res['top10_call_avg_dura_rate'] = res['top10_call_dura_rate']/res['top10_call_cnt_rate']
            scaler = MinMaxScaler()
            res.loc[:, ['top5_call_avg_dura_rate', 'top10_call_avg_dura_rate']] = scaler.fit_transform(res.loc[:, ['top5_call_avg_dura_rate', 'top10_call_avg_dura_rate']])
        return res
        
# def get_avg_dura_rate(df, night_call=True, top_5=True, top_10=True):
#     df['night_call_avg_dura_rate'] = df['night_call_dura_rate']/df['night_call_cnt_rate']
#     df['top5_call_avg_dura_rate'] = df['top5_call_dura_rate']/df['top5_call_cnt_rate']
#     df['top10_call_avg_dura_rate'] = df['top10_call_dura_rate']/df['top10_call_cnt_rate']
#     return df

# %%
c_a_a = CombinedAttributesAdder(add_night, add_top)

# %%
c_a_a.fit_transform(X)
# Out:
#        age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0       25    2             0                1.2726               3.1250
# 1       18    2             0                8.4315               6.9767
# 2       42    1             1                5.0105               7.6923
# 3       28    2             1                1.4925               3.8462
# 4       60    1             0                0.7424               0.6472
# ...    ...  ...           ...                   ...                  ...
# 29404   22    2             0                6.3073              20.0000
# 29405    0    1             1                5.4694               6.1224
# 29406   18    1             0                4.6768               7.4074
# 29407   34    1             0                0.3208               0.7299
# 29408   44    1             0                3.2597               7.1429
#
#        called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0              87.5000              1             2            66.6667
# 1              76.7442              3             3            50.0000
# 2              49.0385              7            13            65.0000
# 3              19.2308              0            21           100.0000
# 4              37.5405             15            12            37.5000
# ...                ...            ...           ...                ...
# 29404         100.0000              0             0             0.0000
# 29405          43.8776              5             1            20.0000
# 29406          48.1481              4            13            54.1667
# 29407          27.7372              9             7            35.0000
# 29408          43.8776              8             5            27.7778
#
#        top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                  72.0020             43.7500                  3
# 1                  99.2148             88.3721                  1
# 2                  64.1474             53.8462                  2
# 3                  45.9242             19.2308                  1
# 4                  69.9878             57.2816                  3
# ...                    ...                 ...                ...
# 29404             100.0000            100.0000                  3
# 29405              99.0246             89.7959                  3
# 29406              45.3232             27.1605                  1
# 29407              82.2456             62.7737                  2
# 29408              67.6509             40.8163                  2
#
#        top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt  \
# 0                   86.5884              62.5000                   3
# 1                  100.0000             100.0000                   3
# 2                   82.2526              71.1538                   3
# 3                   64.0643              38.4615                   1
# 4                   85.1415              70.8738                   3
# ...                     ...                  ...                 ...
# 29404              100.0000             100.0000                   3
# 29405               99.8302              97.9592                   3
# 29406               62.7430              41.9753                   1
# 29407               91.2374              74.4526                   2
# 29408               83.5715              58.1633                   3
#
#        night_call_avg_dura_rate  top5_call_avg_dura_rate  \
# 0                      0.006989                 0.042065
# 1                      0.020823                 0.022605
# 2                      0.011204                 0.025158
# 3                      0.006658                 0.069681
# 4                      0.019762                 0.026293
# ...                         ...                      ...
# 29404                  0.005403                 0.018040
# 29405                  0.015381                 0.021864
# 29406                  0.010859                 0.042919
# 29407                  0.007546                 0.029581
# 29408                  0.007837                 0.042500
#
#        top10_call_avg_dura_rate
# 0                      0.105519
# 1                      0.048665
# 2                      0.071675
# 3                      0.146861
# 4                      0.078361
# ...                         ...
# 29404                  0.048665
# 29405                  0.051483
# 29406                  0.121649
# 29407                  0.081921
# 29408                  0.113105
#
# [28426 rows x 18 columns]

# %%
class KillPercentage(BaseEstimator, TransformerMixin):
    def __init__(self):
        return None
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        res = X.copy()
        for col in res.columns:
            if 'rate' in col and 'avg' not in col:
                res[col] = res[col]/100
        return res

# %%
k_p = KillPercentage()

# %%
k_p.fit_transform(X)
# Out:
#        age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0       25    2             0              0.012726             0.031250
# 1       18    2             0              0.084315             0.069767
# 2       42    1             1              0.050105             0.076923
# 3       28    2             1              0.014925             0.038462
# 4       60    1             0              0.007424             0.006472
# ...    ...  ...           ...                   ...                  ...
# 29404   22    2             0              0.063073             0.200000
# 29405    0    1             1              0.054694             0.061224
# 29406   18    1             0              0.046768             0.074074
# 29407   34    1             0              0.003208             0.007299
# 29408   44    1             0              0.032597             0.071429
#
#        called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0             0.875000              1             2           0.666667
# 1             0.767442              3             3           0.500000
# 2             0.490385              7            13           0.650000
# 3             0.192308              0            21           1.000000
# 4             0.375405             15            12           0.375000
# ...                ...            ...           ...                ...
# 29404         1.000000              0             0           0.000000
# 29405         0.438776              5             1           0.200000
# 29406         0.481481              4            13           0.541667
# 29407         0.277372              9             7           0.350000
# 29408         0.438776              8             5           0.277778
#
#        top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                 0.720020            0.437500                  3
# 1                 0.992148            0.883721                  1
# 2                 0.641474            0.538462                  2
# 3                 0.459242            0.192308                  1
# 4                 0.699878            0.572816                  3
# ...                    ...                 ...                ...
# 29404             1.000000            1.000000                  3
# 29405             0.990246            0.897959                  3
# 29406             0.453232            0.271605                  1
# 29407             0.822456            0.627737                  2
# 29408             0.676509            0.408163                  2
#
#        top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt
# 0                  0.865884             0.625000                   3
# 1                  1.000000             1.000000                   3
# 2                  0.822526             0.711538                   3
# 3                  0.640643             0.384615                   1
# 4                  0.851415             0.708738                   3
# ...                     ...                  ...                 ...
# 29404              1.000000             1.000000                   3
# 29405              0.998302             0.979592                   3
# 29406              0.627430             0.419753                   1
# 29407              0.912374             0.744526                   2
# 29408              0.835715             0.581633                   3
#
# [28426 rows x 15 columns]

# %%
class MyScaler(BaseEstimator, TransformerMixin):
    def __init__(self, cols):
        self.cols = cols
        return None
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        res = X.copy()
        scaler = MinMaxScaler()
        res.loc[:, self.cols] = scaler.fit_transform(res.loc[:, self.cols])
        return res

# %%
myscaler = MyScaler(min_max_scale_cols)

# %%
myscaler.fit_transform(X)
# Out:
#             age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0      0.213675    2             0                1.2726               3.1250
# 1      0.153846    2             0                8.4315               6.9767
# 2      0.358974    1             1                5.0105               7.6923
# 3      0.239316    2             1                1.4925               3.8462
# 4      0.512821    1             0                0.7424               0.6472
# ...         ...  ...           ...                   ...                  ...
# 29404  0.188034    2             0                6.3073              20.0000
# 29405  0.000000    1             1                5.4694               6.1224
# 29406  0.153846    1             0                4.6768               7.4074
# 29407  0.290598    1             0                0.3208               0.7299
# 29408  0.376068    1             0                3.2597               7.1429
#
#        called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0              87.5000       0.002882      0.000613            66.6667
# 1              76.7442       0.008646      0.000920            50.0000
# 2              49.0385       0.020173      0.003988            65.0000
# 3              19.2308       0.000000      0.006442           100.0000
# 4              37.5405       0.043228      0.003681            37.5000
# ...                ...            ...           ...                ...
# 29404         100.0000       0.000000      0.000000             0.0000
# 29405          43.8776       0.014409      0.000307            20.0000
# 29406          48.1481       0.011527      0.003988            54.1667
# 29407          27.7372       0.025937      0.002147            35.0000
# 29408          43.8776       0.023055      0.001534            27.7778
#
#        top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                  72.0020             43.7500               0.50
# 1                  99.2148             88.3721               0.00
# 2                  64.1474             53.8462               0.25
# 3                  45.9242             19.2308               0.00
# 4                  69.9878             57.2816               0.50
# ...                    ...                 ...                ...
# 29404             100.0000            100.0000               0.50
# 29405              99.0246             89.7959               0.50
# 29406              45.3232             27.1605               0.00
# 29407              82.2456             62.7737               0.25
# 29408              67.6509             40.8163               0.25
#
#        top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt
# 0                   86.5884              62.5000            0.222222
# 1                  100.0000             100.0000            0.222222
# 2                   82.2526              71.1538            0.222222
# 3                   64.0643              38.4615            0.000000
# 4                   85.1415              70.8738            0.222222
# ...                     ...                  ...                 ...
# 29404              100.0000             100.0000            0.222222
# 29405               99.8302              97.9592            0.222222
# 29406               62.7430              41.9753            0.000000
# 29407               91.2374              74.4526            0.111111
# 29408               83.5715              58.1633            0.222222
#
# [28426 rows x 15 columns]

# %%
_.describe()
# Out:
#                 age           sex  is_camp_user  night_call_dura_rate  \
# count  28426.000000  28426.000000  28426.000000          28426.000000
# mean       0.331314      1.438261      0.156019              6.583765
# std        0.121738      0.516879      0.362880             12.431626
# min        0.000000      1.000000      0.000000              0.002900
# 25%        0.239316      1.000000      0.000000              0.625200
# 50%        0.333333      1.000000      0.000000              2.028000
# 75%        0.427350      2.000000      0.000000              6.430750
# max        1.000000      3.000000      1.000000            100.000000
#
#        night_call_cnt_rate  called_cnt_rate  contact_ratio  once_numbers  \
# count         28426.000000     28426.000000   28426.000000  28426.000000
# mean              6.635213        55.673941       0.017600      0.002462
# std               9.641722        18.297824       0.019241      0.010351
# min               0.025600         0.000000       0.000000      0.000000
# 25%               1.648400        44.162400       0.005764      0.000613
# 50%               3.478300        54.923850       0.011527      0.001534
# 75%               7.692300        66.782600       0.023055      0.002761
# max             100.000000       100.000000       1.000000      1.000000
#
#        once_numbers_rate  top5_call_dura_rate  top5_call_cnt_rate  \
# count       28426.000000         28426.000000        28426.000000
# mean           50.351940            78.951338           64.457406
# std            23.362734            16.542748           21.056556
# min             0.000000             3.386800            0.684500
# 25%            36.363600            68.477350           49.428525
# 50%            50.000000            82.009700           65.625000
# 75%            64.285700            92.555075           80.645200
# max           100.000000           100.000000          100.000000
#
#        top5_opp_belo_cnt  top10_call_dura_rate  top10_call_cnt_rate  \
# count       28426.000000          28426.000000         28426.000000
# mean            0.192262             90.782824            81.192458
# std             0.215223             11.600697            17.435035
# min             0.000000              5.892300             1.206000
# 25%             0.000000             86.428550            70.833300
# 50%             0.250000             95.033650            84.905700
# 75%             0.250000             99.397575            96.000000
# max             1.000000            100.000000           100.000000
#
#        top10_opp_belo_cnt
# count        28426.000000
# mean             0.154831
# std              0.143309
# min              0.000000
# 25%              0.000000
# 50%              0.111111
# 75%              0.222222
# max              1.000000

# %%
num_pipeline = Pipeline([
    ('add_combined_attr', CombinedAttributesAdder(False, False)),
    ('kill_percentage',KillPercentage()),
    ('min_max_scaler', MyScaler(min_max_scale_cols))])

# %%
X_ = num_pipeline.fit_transform(X)

# %%
X_
# Out:
#             age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0      0.213675    2             0              0.012726             0.031250
# 1      0.153846    2             0              0.084315             0.069767
# 2      0.358974    1             1              0.050105             0.076923
# 3      0.239316    2             1              0.014925             0.038462
# 4      0.512821    1             0              0.007424             0.006472
# ...         ...  ...           ...                   ...                  ...
# 29404  0.188034    2             0              0.063073             0.200000
# 29405  0.000000    1             1              0.054694             0.061224
# 29406  0.153846    1             0              0.046768             0.074074
# 29407  0.290598    1             0              0.003208             0.007299
# 29408  0.376068    1             0              0.032597             0.071429
#
#        called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0             0.875000       0.002882      0.000613           0.666667
# 1             0.767442       0.008646      0.000920           0.500000
# 2             0.490385       0.020173      0.003988           0.650000
# 3             0.192308       0.000000      0.006442           1.000000
# 4             0.375405       0.043228      0.003681           0.375000
# ...                ...            ...           ...                ...
# 29404         1.000000       0.000000      0.000000           0.000000
# 29405         0.438776       0.014409      0.000307           0.200000
# 29406         0.481481       0.011527      0.003988           0.541667
# 29407         0.277372       0.025937      0.002147           0.350000
# 29408         0.438776       0.023055      0.001534           0.277778
#
#        top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                 0.720020            0.437500                0.6
# 1                 0.992148            0.883721                0.2
# 2                 0.641474            0.538462                0.4
# 3                 0.459242            0.192308                0.2
# 4                 0.699878            0.572816                0.6
# ...                    ...                 ...                ...
# 29404             1.000000            1.000000                0.6
# 29405             0.990246            0.897959                0.6
# 29406             0.453232            0.271605                0.2
# 29407             0.822456            0.627737                0.4
# 29408             0.676509            0.408163                0.4
#
#        top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt
# 0                  0.865884             0.625000                 0.3
# 1                  1.000000             1.000000                 0.3
# 2                  0.822526             0.711538                 0.3
# 3                  0.640643             0.384615                 0.1
# 4                  0.851415             0.708738                 0.3
# ...                     ...                  ...                 ...
# 29404              1.000000             1.000000                 0.3
# 29405              0.998302             0.979592                 0.3
# 29406              0.627430             0.419753                 0.1
# 29407              0.912374             0.744526                 0.2
# 29408              0.835715             0.581633                 0.3
#
# [29409 rows x 15 columns]

# %%
y_ = y

# %%
y_
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29404    0
# 29405    0
# 29406    0
# 29407    0
# 29408    0
# Name: label, Length: 29409, dtype: int64

# %%
lgb_clf.fit(X_, y_)
# Out:
# LGBMClassifier()

# %%
X_test = num_pipeline.transform(X_test)

# %%
y_pred = lgb_clf.predict(X_test)

# %%
fbeta_score(y_test, y_pred, beta=2)
# Out:
# 0.7804690503652442

# %% [markdown]
# 数据处理流水线

# %%
from sklearn.pipeline import Pipeline

# %%
add_night = False
add_top = False

# %%
num_pipeline = Pipeline([
    ('add_combined_attr', CombinedAttributesAdder(add_night, add_top)),
    ('kill_percentage',KillPercentage()),
    ('min_max_scaler', MyScaler(min_max_scale_cols))])

# %%
data = train.copy()
dropper = DropInvalidData(add_night=add_night, add_top=add_top)
data = dropper.fit_transform(data)
X = data.drop(columns=['label'])
y = data['label']

# %%
X_train = num_pipeline.fit_transform(X)
y_train = y

# %%
train_processed = pd.concat([X_train, y_train], axis=1)

# %%
train_processed
# Out:
#             age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0      0.213675    2             0              0.012726             0.031250
# 1      0.153846    2             0              0.084315             0.069767
# 2      0.358974    1             1              0.050105             0.076923
# 3      0.239316    2             1              0.014925             0.038462
# 4      0.512821    1             0              0.007424             0.006472
# ...         ...  ...           ...                   ...                  ...
# 29404  0.188034    2             0              0.063073             0.200000
# 29405  0.000000    1             1              0.054694             0.061224
# 29406  0.153846    1             0              0.046768             0.074074
# 29407  0.290598    1             0              0.003208             0.007299
# 29408  0.376068    1             0              0.032597             0.071429
#
#        called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0             0.875000       0.002882      0.000613           0.666667
# 1             0.767442       0.008646      0.000920           0.500000
# 2             0.490385       0.020173      0.003988           0.650000
# 3             0.192308       0.000000      0.006442           1.000000
# 4             0.375405       0.043228      0.003681           0.375000
# ...                ...            ...           ...                ...
# 29404         1.000000       0.000000      0.000000           0.000000
# 29405         0.438776       0.014409      0.000307           0.200000
# 29406         0.481481       0.011527      0.003988           0.541667
# 29407         0.277372       0.025937      0.002147           0.350000
# 29408         0.438776       0.023055      0.001534           0.277778
#
#        top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                 0.720020            0.437500                0.6
# 1                 0.992148            0.883721                0.2
# 2                 0.641474            0.538462                0.4
# 3                 0.459242            0.192308                0.2
# 4                 0.699878            0.572816                0.6
# ...                    ...                 ...                ...
# 29404             1.000000            1.000000                0.6
# 29405             0.990246            0.897959                0.6
# 29406             0.453232            0.271605                0.2
# 29407             0.822456            0.627737                0.4
# 29408             0.676509            0.408163                0.4
#
#        top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt  label
# 0                  0.865884             0.625000                 0.3      0
# 1                  1.000000             1.000000                 0.3      0
# 2                  0.822526             0.711538                 0.3      0
# 3                  0.640643             0.384615                 0.1      0
# 4                  0.851415             0.708738                 0.3      0
# ...                     ...                  ...                 ...    ...
# 29404              1.000000             1.000000                 0.3      0
# 29405              0.998302             0.979592                 0.3      0
# 29406              0.627430             0.419753                 0.1      0
# 29407              0.912374             0.744526                 0.2      0
# 29408              0.835715             0.581633                 0.3      0
#
# [29409 rows x 16 columns]

# %%
train_processed.describe()
# Out:
#                 age           sex  is_camp_user  night_call_dura_rate  \
# count  29409.000000  29409.000000  29409.000000          29409.000000
# mean       0.332343      1.437145      0.152334              0.063639
# std        0.123169      0.516132      0.359351              0.122792
# min        0.000000      1.000000      0.000000              0.000000
# 25%        0.239316      1.000000      0.000000              0.005376
# 50%        0.333333      1.000000      0.000000              0.018868
# 75%        0.427350      2.000000      0.000000              0.061421
# max        1.000000      3.000000      1.000000              1.000000
#
#        night_call_cnt_rate  called_cnt_rate  contact_ratio  once_numbers  \
# count         29409.000000     29409.000000   29409.000000  29409.000000
# mean              0.064134         0.549025       0.017208      0.002807
# std               0.095539         0.194724       0.019233      0.013915
# min               0.000000         0.000000       0.000000      0.000000
# 25%               0.014925         0.434783       0.005764      0.000613
# 50%               0.033333         0.545673       0.011527      0.001534
# 75%               0.074074         0.666667       0.023055      0.002761
# max               1.000000         1.000000       1.000000      1.000000
#
#        once_numbers_rate  top5_call_dura_rate  top5_call_cnt_rate  \
# count       29409.000000         29409.000000        29409.000000
# mean            0.501616             0.780639            0.637422
# std             0.240790             0.185325            0.222563
# min             0.000000             0.000000            0.000000
# 25%             0.357143             0.678597            0.485075
# 50%             0.500000             0.818273            0.653061
# 75%             0.648649             0.925796            0.806630
# max             1.000000             1.000000            1.000000
#
#        top5_opp_belo_cnt  top10_call_dura_rate  top10_call_cnt_rate  \
# count       29409.000000          29409.000000         29409.000000
# mean            0.354721              0.897297             0.802162
# std             0.179600              0.149514             0.195700
# min             0.000000              0.000000             0.000000
# 25%             0.200000              0.859572             0.701923
# 50%             0.400000              0.949586             0.847291
# 75%             0.400000              0.994194             0.961039
# max             1.000000              1.000000             1.000000
#
#        top10_opp_belo_cnt         label
# count        29409.000000  29409.000000
# mean             0.241504      0.054779
# std              0.138494      0.227553
# min              0.000000      0.000000
# 25%              0.100000      0.000000
# 50%              0.200000      0.000000
# 75%              0.300000      0.000000
# max              1.000000      1.000000

# %% [markdown]
# # 模型检索（使用默认超参数）

# %% [markdown]
# 因为是有监督的二分类任务，考虑下列模型：
# - 逻辑回归
# - SVM分类
# - 决策树
# - 随机森林
# - XGBoost
# - LightGBM

# %% [markdown]
# 手动交叉验证

# %%
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.base import clone
from sklearn.metrics import precision_score, recall_score, fbeta_score, precision_recall_curve, roc_auc_score

# %%
def my_cross_val_score(model, X_train, y_train, isStratified=True, usePredProb=False):
    if isStratified:
        skfolds = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    else:
        skfolds = KFold(n_splits=5, shuffle=True, random_state=42)
        
    scores = {'precision': [],
              'recall': [],
              'fbeta_score': []}
    y_pred_prb = np.zeros(shape=y_train.shape)
    
    for train_indices, valid_indices in skfolds.split(X_train, y_train):
        clone_clf = clone(model)

        X_train_folds = X_train.iloc[train_indices, :]
        y_train_folds = y_train.iloc[train_indices]
        X_valid_fold = X_train.iloc[valid_indices, :]
        y_valid_fold = y_train.iloc[valid_indices]

        clone_clf.fit(X_train_folds, y_train_folds)
        
        y_pred = clone_clf.predict(X_valid_fold)
        if usePredProb:
            y_pred_prb[valid_indices] = clone_clf.predict_proba(X_valid_fold)[:,1]
        else:
            y_pred_prb[valid_indices] = clone_clf.decision_function(X_valid_fold)
        
        scores['precision'].append(precision_score(y_valid_fold, y_pred))
        scores['recall'].append(recall_score(y_valid_fold, y_pred))
        scores['fbeta_score'].append(fbeta_score(y_valid_fold, y_pred, beta=2))
    
    print("5折交叉验证的结果为: \n precision: {}({}) \n recall: {}({}) \n fbeta_score: {}({})".format(np.mean(scores['precision']),
                                                                                                    np.std(scores['precision']),
                                                                                                    np.mean(scores['recall']),
                                                                                                    np.std(scores['recall']),
                                                                                                    np.mean(scores['fbeta_score']),
                                                                                                    np.std(scores['fbeta_score'])))
    scores['auc'] = roc_auc_score(y_train, y_pred_prb)
    print(" auc: {}".format(scores['auc']))
    
    precisions, recalls, thresholds = precision_recall_curve(y_train, y_pred_prb)
    scores['p_r_curve'] = (precisions, recalls, thresholds)
    
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    plt.plot(recalls, precisions)
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')
    ax.grid()
    ax.set_title("P-R Curve")
    
    # fig = plt.figure()
    # ax = fig.add_subplot(1,1,1)
    # plt.plot(thresholds, precisions[:-1], "b--", label='Precision')
    # plt.plot(thresholds, recalls[:-1], "g-", label='Recall')
    # ax.legend()
    # ax.set_xlabel('thresholds')
    # ax.grid()
    
    return scores

# %%
logistic_reg = LogisticRegression(max_iter=1000)

# %%
scores_lr = my_cross_val_score(logistic_reg, X_train, y_train)
# Out:
# 5折交叉验证的结果为:
#  precision: 0.9703596540513215(0.020711436117254425)
#  recall: 0.3562890602465242(0.015231142644846467)
#  fbeta_score: 0.40782442175148603(0.015762469950208958)
#  auc: 0.8183345764506904

# %% [markdown]
# 从P-R曲线可以看到，随着召回率的上升，查准率下降先快后慢；
#
# 考虑到任务本身的性质，可以选择召回率为0.8-1.0的阈值

# %%
logistic_reg = LogisticRegression(max_iter=1000)

# %%
scores = my_cross_val_score(logistic_reg, X_train, y_train, False)
# 在划分验证集时不分层，评估结果的标准差增大
# Out:
# 5折交叉验证的结果为:
#  precision: 0.97131998106161(0.013880625600025166)
#  recall: 0.3590111841707282(0.008841588103939852)
#  fbeta_score: 0.41078209513411307(0.009359604327992611)
#  auc: 0.8183240366376406

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
scores_svc = my_cross_val_score(svc, X_train, y_train)
# Out:
# 5折交叉验证的结果为:
#  precision: 0.9964887964887964(0.004302809499422516)
#  recall: 0.3382958675461031(0.014212604242965133)
#  fbeta_score: 0.38973038063304183(0.014990491814358058)
#  auc: 0.852885691395435

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
scores_dtc = my_cross_val_score(dtc, X_train, y_train, usePredProb=True)
# Out:
# 5折交叉验证的结果为:
#  precision: 0.6976448641353554(0.013845177486660752)
#  recall: 0.7467203815164509(0.025979470835711373)
#  fbeta_score: 0.7360312464407538(0.017827394299701378)
#  auc: 0.863963425687552

# %% [markdown]
# bagging: random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
scores_rfc = my_cross_val_score(rfc, X_train, y_train, usePredProb=True)
# Out:
# 5折交叉验证的结果为:
#  precision: 0.9899249601051562(0.0055944439841632086)
#  recall: 0.7231352037382459(0.022540951637376305)
#  fbeta_score: 0.7642157813008537(0.019773618199654105)
#  auc: 0.9302599216150531

# %% [markdown]
# 查看特征重要性

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
importance_dic = {}
for importance, feature_name in zip(rfc.feature_importances_, X_train.columns):
    importance_dic[feature_name] = [importance]

# %%
importance_dic
# Out:
# {'age': [0.05737916414178686],
#  'sex': [0.008442910649459403],
#  'is_camp_user': [0.004708789784315604],
#  'night_call_dura_rate': [0.059041623978715416],
#  'night_call_cnt_rate': [0.05839257227948811],
#  'called_cnt_rate': [0.05536250505194348],
#  'contact_ratio': [0.039705643980653973],
#  'once_numbers': [0.08269641061005788],
#  'once_numbers_rate': [0.0402810176190831],
#  'top5_call_dura_rate': [0.06553876493704808],
#  'top5_call_cnt_rate': [0.056655595991380245],
#  'top5_opp_belo_cnt': [0.03766617563514936],
#  'top10_call_dura_rate': [0.07297717258920643],
#  'top10_call_cnt_rate': [0.07387227084249158],
#  'top10_opp_belo_cnt': [0.12071176029058854],
#  'night_call_avg_dura_rate': [0.05848007175800879],
#  'top5_call_avg_dura_rate': [0.05456960379611785],
#  'top10_call_avg_dura_rate': [0.05351794606450527]}

# %%
pd.DataFrame(data=importance_dic.values(), index=importance_dic.keys(),columns=['importance']).sort_values(by=['importance'], ascending=False)
# 可以看到添加的几个新属性表现还不错
# Out:
#                           importance
# top10_opp_belo_cnt          0.120712
# once_numbers                0.082696
# top10_call_cnt_rate         0.073872
# top10_call_dura_rate        0.072977
# top5_call_dura_rate         0.065539
# night_call_dura_rate        0.059042
# night_call_avg_dura_rate    0.058480
# night_call_cnt_rate         0.058393
# age                         0.057379
# top5_call_cnt_rate          0.056656
# called_cnt_rate             0.055363
# top5_call_avg_dura_rate     0.054570
# top10_call_avg_dura_rate    0.053518
# once_numbers_rate           0.040281
# contact_ratio               0.039706
# top5_opp_belo_cnt           0.037666
# sex                         0.008443
# is_camp_user                0.004709

# %% [markdown]
# boosting: XGBoost、LightGBM

# %%
import xgboost
from xgboost.sklearn import XGBClassifier

# %%
xgb_clf = XGBClassifier()

# %%
scores_xgb = my_cross_val_score(xgb_clf, X_train, y_train, usePredProb=True)
# Out:
# 5折交叉验证的结果为:
#  precision: 0.8509416704153546(0.043244708214533835)
#  recall: 0.32123174603174603(0.04685582826047694)
#  fbeta_score: 0.36624000915679594(0.04912980770558573)
#  auc: 0.8244431451210008

# %%
from lightgbm.sklearn import LGBMClassifier

# %%
lgb_clf = LGBMClassifier()

# %%
scores_lgb = my_cross_val_score(lgb_clf, X_train, y_train, usePredProb=True)
# Out:
# 5折交叉验证的结果为:
#  precision: 0.8618131868131869(0.07232484552582073)
#  recall: 0.3228190476190476(0.037246819097472184)
#  fbeta_score: 0.3684702648220544(0.03963831850810991)
#  auc: 0.8345432846003158

# %% [markdown]
# voting

# %%
from sklearn.ensemble import VotingClassifier

# %%
logistic_reg = LogisticRegression()
svc = SVC(probability=True)
dtc = DecisionTreeClassifier()
rfc = RandomForestClassifier()
xgb_clf = XGBClassifier()
lgb_clf = LGBMClassifier()

# %% [markdown]
# 使用网格搜索来来寻找最佳的集成

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %%
param_grid = [{'estimators': [
                # 集成全部模型
                [('lr', logistic_reg), 
                ('svm', svc),
                ('dtc', dtc),
                ('rfc', rfc),
                ('xgb', xgb_clf),
                ('lgb', lgb_clf)],
                # 仅集成在recall上表现好的前4名
                [('decision_tree', dtc),
                 ('rfc', rfc),
                 ('xgb', xgb_clf),
                 ('lgb', lgb_clf)],
                # 仅集成在recall上表现好的前3名
                [('decision_tree', dtc),
                 ('xgb', xgb_clf),
                 ('lgb', lgb_clf)],
                # 仅集成“优质”学习器
                [('rfc', rfc),
                 ('xgb', xgb_clf),
                 ('lgb', lgb_clf)]]}]

# %%
voting_clf = VotingClassifier(estimators=[], voting='soft')

# %%
def myfbeta(y_true, y_pred):
    return fbeta_score(y_true, y_pred, beta=2)

# %%
fbeta = make_scorer(myfbeta, greater_is_better=True)

# %%
grid_search = GridSearchCV(voting_clf, param_grid, cv=5, scoring=fbeta, return_train_score=True)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=VotingClassifier(estimators=[], voting='soft'),
#              param_grid=[{'estimators': [[('lr', LogisticRegression()),
#                                           ('svm', SVC(probability=True)),
#                                           ('dtc', DecisionTreeClassifier()),
#                                           ('rfc', RandomForestClassifier()),
#                                           ('xgb',
#                                            XGBClassifier(base_score=None,
#                                                          booster=None,
#                                                          callbacks=None,
#                                                          colsample_bylevel=None,
#                                                          colsample_bynode=None,
#                                                          colsample_bytr...
#                                                          learning_rate=None,
#                                                          max_bin=None,
#                                                          max_cat_threshold=None,
#                                                          max_cat_to_onehot=None,
#                                                          max_delta_step=None,
#                                                          max_depth=None,
#                                                          max_leaves=None,
#                                                          min_child_weight=None,
#                                                          missing=nan,
#                                                          monotone_constraints=None,
#                                                          n_estimators=100,
#                                                          n_jobs=None,
#                                                          num_parallel_tree=None,
#                                                          predictor=None,
#                                                          random_state=None, ...)),
#                                           ('lgb', LGBMClassifier())]]}],
#              return_train_score=True, scoring=make_scorer(myfbeta))

# %%
grid_search.best_params_
# Out:
# {'estimators': [('decision_tree', DecisionTreeClassifier()),
#   ('xgb',
#    XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...)),
#   ('lgb', LGBMClassifier())]}

# %%
cvres = grid_search.cv_results_

# %%
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(mean_score, params)
# Out:
# 0.34908911743935966 {'estimators': [('lr', LogisticRegression()), ('svm', SVC(probability=True)), ('dtc', DecisionTreeClassifier()), ('rfc', RandomForestClassifier()), ('xgb', XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)), ('lgb', LGBMClassifier())]}
# 0.3704283917802226 {'estimators': [('decision_tree', DecisionTreeClassifier()), ('rfc', RandomForestClassifier()), ('xgb', XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)), ('lgb', LGBMClassifier())]}
# 0.3778970500414657 {'estimators': [('decision_tree', DecisionTreeClassifier()), ('xgb', XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)), ('lgb', LGBMClassifier())]}
# 0.3686076450571297 {'estimators': [('rfc', RandomForestClassifier()), ('xgb', XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)), ('lgb', LGBMClassifier())]}

# %% [markdown]
# 最好的集成是仅集成在recall上表现好的前三名

# %%
voting_clf = VotingClassifier(
    estimators=[('dtc', dtc),
                ('xgb', xgb_clf),
                ('lgb', lgb_clf)],
    voting='soft')

# %%
scores_voting = my_cross_val_score(voting_clf, X_train, y_train, usePredProb=True)
# Out:
# 5折交叉验证的结果为:
#  precision: 0.8536691465200464(0.035337848399990886)
#  recall: 0.3132825396825397(0.04920198895172065)
#  fbeta_score: 0.35825713618225363(0.052654238346013585)
#  auc: 0.8390209555273919

# %%
voting_clf2 = VotingClassifier(
    estimators=[('decision_tree', dtc),
                 ('rfc', rfc),
                 ('xgb', xgb_clf),
                 ('lgb', lgb_clf)],
    voting='soft')
voting_clf3 = VotingClassifier(
    estimators=[('rfc', rfc),
                 ('xgb', xgb_clf),
                 ('lgb', lgb_clf)],
    voting='soft')

# %%
scores_voting2 = my_cross_val_score(voting_clf2, X_train, y_train, usePredProb=True)
scores_voting3 = my_cross_val_score(voting_clf3, X_train, y_train, usePredProb=True)
# Out:
# 5折交叉验证的结果为:
#  precision: 0.8951933704038968(0.04105390446255575)
#  recall: 0.31010793650793655(0.04882859856986272)
#  fbeta_score: 0.35635150464019627(0.05278415317271223)
#  auc: 0.8352780003423642
# 5折交叉验证的结果为:
#  precision: 0.8961611221569628(0.05317479837272878)
#  recall: 0.31169523809523814(0.042578923384149675)
#  fbeta_score: 0.35800283348919404(0.04579840459561578)
#  auc: 0.8394990412262696

# %%
def draw_p_r_curve(scores_dic):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(1,1,1)
    for index, (model_name, model_scores) in enumerate(scores_dic.items()):
        p, r, t = model_scores['p_r_curve']
        plt.plot(r, p, 'C{}'.format(index), label=model_name)
        
    x = np.arange(0, 1.2, 0.2)
    y = x
    plt.plot(x, y, 'k--', alpha=0.5)    
    
    ax.grid()
    ax.legend()
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')
    ax.set_title('P-R curve')
    plt.show()

# %%
scores_dic = {
              # 'logistic_reg': scores_lr,
              # 'svc': scores_svc,
              # 'decision_tree': scores_dtc,
              # 'random_forest': scores_rfc,
              # 'xgb':scores_xgb,
              # 'lgb': scores_lgb,
              'voting(tree+xgb+lgb)': scores_voting,
              'voting(tree+rf+lgb+xgb': scores_voting2,
              'voting(rf+lgb+xgb)': scores_voting3
}

# %%
draw_p_r_curve(scores_dic)

# %%
scores_dic = {
              'logistic_reg': scores_lr,
              'svc': scores_svc,
              'decision_tree': scores_dtc,
              'random_forest': scores_rfc,
              'xgb':scores_xgb,
              'lgb': scores_lgb,
              'voting(dtc+xgb+lgb)': scores_voting,
}

# %%
draw_p_r_curve(scores_dic)

# %% [markdown]
# - 根据平衡点对各模型的排名:
# random_forest> lgb > xgb > svc > voting > logistic_reg > decision_tree
#
# - 当precision设置为0.2时，recall的排名:
# decision_tree > lgb > voting > xgb > random_forest > logistic_reg > svc

# %% [markdown]
# 查看f2排名

# %%
scores_dic = {
              'logistic_reg': scores_lr,
              'svc': scores_svc,
              'decision_tree': scores_dtc,
              'random_forest': scores_rfc,
              'xgb':scores_xgb,
              'lgb': scores_lgb,
              'voting(dtc+xgb+lgb)': scores_voting,
}

# %%
fbeta_scores_dic = {}
for model_name, scores in scores_dic.items():
    fbeta_scores_dic[model_name] =  np.mean(scores['fbeta_score'])

# %%
pd.DataFrame(data=fbeta_scores_dic.values(), index=fbeta_scores_dic.keys(), columns=['f2']).sort_values(by=['f2'], ascending=False)
# Out:
#                            f2
# lgb                  0.368470
# xgb                  0.366240
# voting(dtc+xgb+lgb)  0.358257
# decision_tree        0.346365
# random_forest        0.338729
# logistic_reg         0.212384
# svc                  0.172515

# %% [markdown]
# 最后选择lgb模型作为最终模型

# %% [markdown]
# # 微调

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# 在调查是否添加新属性时使用去除所有invalid数据后的数据集，和表现不错的random_forest模型

# %%
num_pipeline = Pipeline([
    ('add_combined_attr', CombinedAttributesAdder()),
    ('kill_percentage',KillPercentage()),
    ('min_max_scaler', MyScaler(min_max_scale_cols))])

# %%
add_night = True
add_top = True

data = train.copy()
dropper = DropInvalidData(add_night=add_night, add_top=add_top)
data = dropper.fit_transform(data)
X = data.drop(columns=['label'])
y = data['label']

# %%
full_pipeline = Pipeline([
    ('data_process', num_pipeline),
    # ('spliter', spliter),
    ('lgb',LGBMClassifier())
])

# %%
full_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('data_process',
#    Pipeline(steps=[('add_combined_attr', CombinedAttributesAdder()),
#                    ('kill_percentage', KillPercentage()),
#                    ('min_max_scaler',
#                     MyScaler(cols=['age', 'contact_ratio', 'once_numbers',
#                                    'top5_opp_belo_cnt', 'top10_opp_belo_cnt']))])),
#   ('lgb', LGBMClassifier())],
#  'verbose': False,
#  'data_process': Pipeline(steps=[('add_combined_attr', CombinedAttributesAdder()),
#                  ('kill_percentage', KillPercentage()),
#                  ('min_max_scaler',
#                   MyScaler(cols=['age', 'contact_ratio', 'once_numbers',
#                                  'top5_opp_belo_cnt', 'top10_opp_belo_cnt']))]),
#  'lgb': LGBMClassifier(),
#  'data_process__memory': None,
#  'data_process__steps': [('add_combined_attr', CombinedAttributesAdder()),
#   ('kill_percentage', KillPercentage()),
#   ('min_max_scaler',
#    MyScaler(cols=['age', 'contact_ratio', 'once_numbers', 'top5_opp_belo_cnt',
#                   'top10_opp_belo_cnt']))],
#  'data_process__verbose': False,
#  'data_process__add_combined_attr': CombinedAttributesAdder(),
#  'data_process__kill_percentage': KillPercentage(),
#  'data_process__min_max_scaler': MyScaler(cols=['age', 'contact_ratio', 'once_numbers', 'top5_opp_belo_cnt',
#                 'top10_opp_belo_cnt']),
#  'data_process__add_combined_attr__add_night': True,
#  'data_process__add_combined_attr__add_top': True,
#  'data_process__min_max_scaler__cols': ['age',
#   'contact_ratio',
#   'once_numbers',
#   'top5_opp_belo_cnt',
#   'top10_opp_belo_cnt'],
#  'lgb__boosting_type': 'gbdt',
#  'lgb__class_weight': None,
#  'lgb__colsample_bytree': 1.0,
#  'lgb__importance_type': 'split',
#  'lgb__learning_rate': 0.1,
#  'lgb__max_depth': -1,
#  'lgb__min_child_samples': 20,
#  'lgb__min_child_weight': 0.001,
#  'lgb__min_split_gain': 0.0,
#  'lgb__n_estimators': 100,
#  'lgb__n_jobs': -1,
#  'lgb__num_leaves': 31,
#  'lgb__objective': None,
#  'lgb__random_state': None,
#  'lgb__reg_alpha': 0.0,
#  'lgb__reg_lambda': 0.0,
#  'lgb__silent': 'warn',
#  'lgb__subsample': 1.0,
#  'lgb__subsample_for_bin': 200000,
#  'lgb__subsample_freq': 0}

# %%
param_grid = [{'data_process__add_combined_attr__add_night': [True, False], 'data_process__add_combined_attr__add_top': [True, False],
               'lgb__learning_rate': [0.05, 0.1, 0.3], 'lgb__n_estimators': [100, 500, 1000] }]

# %%
grid_search_final = GridSearchCV(estimator=full_pipeline,
                                 param_grid=param_grid,
                                 cv=5,
                                 scoring=fbeta,
                                 return_train_score=True,
                                 refit=True)

# %%
grid_search_final.fit(X, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('data_process',
#                                         Pipeline(steps=[('add_combined_attr',
#                                                          CombinedAttributesAdder()),
#                                                         ('kill_percentage',
#                                                          KillPercentage()),
#                                                         ('min_max_scaler',
#                                                          MyScaler(cols=['age',
#                                                                         'contact_ratio',
#                                                                         'once_numbers',
#                                                                         'top5_opp_belo_cnt',
#                                                                         'top10_opp_belo_cnt']))])),
#                                        ('lgb', LGBMClassifier())]),
#              param_grid=[{'data_process__add_combined_attr__add_night': [True,
#                                                                          False],
#                           'data_process__add_combined_attr__add_top': [True,
#                                                                        False],
#                           'lgb__learning_rate': [0.05, 0.1, 0.3],
#                           'lgb__n_estimators': [100, 500, 1000]}],
#              return_train_score=True, scoring=make_scorer(myfbeta))

# %%
grid_search_final.best_params_
# Out:
# {'data_process__add_combined_attr__add_night': False,
#  'data_process__add_combined_attr__add_top': False,
#  'lgb__learning_rate': 0.05,
#  'lgb__n_estimators': 100}

# %% [markdown]
# 增加列的行为并不会改善fbeta, 但是会改善auc_roc

# %%
model = grid_search_final.best_estimator_

# %%
grid_search_final.best_score_
# Out:
# 0.37819908301213945

# %% [markdown]
# 由于无需增加列，故使用全量数据重新训练模型

# %%
add_night = False
add_top = False

data = train.copy()
dropper = DropInvalidData(add_night=add_night, add_top=add_top)
data = dropper.fit_transform(data)
X = data.drop(columns=['label'])
y = data['label']

# %%
num_pipeline = Pipeline([
    ('add_combined_attr', CombinedAttributesAdder(add_night, add_top)),
    ('kill_percentage',KillPercentage()),
    ('min_max_scaler', MyScaler(min_max_scale_cols))])

# %%
full_pipeline = Pipeline([
    ('data_process', num_pipeline),
    # ('spliter', spliter),
    ('lgb',LGBMClassifier(learning_rate=0.05))
])

# %%
model = full_pipeline.fit(X, y)

# %% [markdown]
# # 评估

# %%
test = pd.read_csv('./data/test.csv')

# %%
test
# Out:
#       age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0      35    1             0                3.3557               5.2083
# 1      44    1             0                2.3340               3.6000
# 2      30    1             0                3.1592               1.8868
# 3      67    1             0                0.0000               0.0000
# 4      29    1             0                2.8661               1.0791
# ...   ...  ...           ...                   ...                  ...
# 9729   62    2             0                1.0515               3.4483
# 9730   44    1             0               56.9288              66.6667
# 9731   53    1             0                0.6517               2.5510
# 9732   31    2             0                1.3945               1.8519
# 9733   63    2             0                1.3134               0.3226
#
#       called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0             64.5833              9             3            33.3333
# 1             59.6000             16            35            67.3077
# 2             41.5094              6             7            50.0000
# 3             50.0000              3             8            72.7273
# 4             44.2446             13            23            51.1111
# ...               ...            ...           ...                ...
# 9729          58.6207              2             3            50.0000
# 9730          33.3333              0             4           100.0000
# 9731          44.6429             20            18            42.8571
# 9732          68.5185              5             3            27.2727
# 9733          64.1935             14            14            48.2759
#
#       top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                 78.0651             56.2500                  1
# 1                 28.4382             10.4000                  1
# 2                 55.2233             49.0566                  1
# 3                 82.8697             37.5000                  2
# 4                 57.4978             37.7698                  1
# ...                   ...                 ...                ...
# 9729              87.0504             86.2069                  2
# 9730             100.0000            100.0000                  2
# 9731              46.6541             30.8673                  1
# 9732              92.7083             87.6543                  3
# 9733              64.5552             56.7742                  2
#
#       top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt  label
# 0                  92.1427              81.2500                   1      0
# 1                  46.2030              23.6000                   1      0
# 2                  79.0649              69.8113                   1      0
# 3                  93.3797              78.1250                   2      1
# 4                  71.5094              51.7986                   1      1
# ...                    ...                  ...                 ...    ...
# 9729              100.0000             100.0000                   2      0
# 9730              100.0000             100.0000                   2      0
# 9731               72.6765              63.5204                   1      0
# 9732               98.5047              96.9136                   4      0
# 9733               82.2303              80.0000                   2      0
#
# [9734 rows x 16 columns]

# %%
X_test = test.drop(columns=['label'], axis=0)

# %%
X_test
# Out:
#       age  sex  is_camp_user  night_call_dura_rate  night_call_cnt_rate  \
# 0      35    1             0                3.3557               5.2083
# 1      44    1             0                2.3340               3.6000
# 2      30    1             0                3.1592               1.8868
# 3      67    1             0                0.0000               0.0000
# 4      29    1             0                2.8661               1.0791
# ...   ...  ...           ...                   ...                  ...
# 9729   62    2             0                1.0515               3.4483
# 9730   44    1             0               56.9288              66.6667
# 9731   53    1             0                0.6517               2.5510
# 9732   31    2             0                1.3945               1.8519
# 9733   63    2             0                1.3134               0.3226
#
#       called_cnt_rate  contact_ratio  once_numbers  once_numbers_rate  \
# 0             64.5833              9             3            33.3333
# 1             59.6000             16            35            67.3077
# 2             41.5094              6             7            50.0000
# 3             50.0000              3             8            72.7273
# 4             44.2446             13            23            51.1111
# ...               ...            ...           ...                ...
# 9729          58.6207              2             3            50.0000
# 9730          33.3333              0             4           100.0000
# 9731          44.6429             20            18            42.8571
# 9732          68.5185              5             3            27.2727
# 9733          64.1935             14            14            48.2759
#
#       top5_call_dura_rate  top5_call_cnt_rate  top5_opp_belo_cnt  \
# 0                 78.0651             56.2500                  1
# 1                 28.4382             10.4000                  1
# 2                 55.2233             49.0566                  1
# 3                 82.8697             37.5000                  2
# 4                 57.4978             37.7698                  1
# ...                   ...                 ...                ...
# 9729              87.0504             86.2069                  2
# 9730             100.0000            100.0000                  2
# 9731              46.6541             30.8673                  1
# 9732              92.7083             87.6543                  3
# 9733              64.5552             56.7742                  2
#
#       top10_call_dura_rate  top10_call_cnt_rate  top10_opp_belo_cnt
# 0                  92.1427              81.2500                   1
# 1                  46.2030              23.6000                   1
# 2                  79.0649              69.8113                   1
# 3                  93.3797              78.1250                   2
# 4                  71.5094              51.7986                   1
# ...                    ...                  ...                 ...
# 9729              100.0000             100.0000                   2
# 9730              100.0000             100.0000                   2
# 9731               72.6765              63.5204                   1
# 9732               98.5047              96.9136                   4
# 9733               82.2303              80.0000                   2
#
# [9734 rows x 15 columns]

# %%
y_test = test['label']

# %%
y_pred = model.predict(X_test)

# %%
fbeta_score(y_test, y_pred, beta=2)
# Out:
# 0.7806476484194296

# %%
y_pred_prob = model.predict_proba(X_test)

# %%
roc_auc_score(y_test, y_pred_prob[:,1])
# Out:
# 0.9214631472828523

# %% [markdown]
# 使用全量数据集之后评估指标飙升，说先前删除的那部分数据可能对预测有着至关重要的作用

# %% [markdown]
# 因此摒弃删除invalid行的想法，重新训练模型

# %% [markdown]
# 混淆矩阵

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[9177,   13],
#        [ 139,  405]], dtype=int64)

# %% [markdown]
# 欺诈用户中有405位被检测出来，仍然有139位未被检测出
